# %% [markdown]
# <a href="https://colab.research.google.com/github/fabrito2006/lab02-l-p/blob/develop/Lab02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SEMANA 2: METODOLOGÍA CRISP-DM. METODOLOGÍA SEMMA
# # Laboratorio Calificado 2
#
# ## Integrantes:
# ## Torres Alvarado, Fabricio Ismael

# %% [markdown]
# ## Entedimiento del negocio
# ### Objetivos:
# ### - Desarrollar un modelo de clasificación que pueda predecir si una persona es diabética o no
# ### - Predecir si una persona tiene diabetes o no

# %% [markdown]
# ## Entendimiento de los datos

# %%
import pandas as pd

# %%
# Leemos base de datos
diabetes = pd.read_csv('diabetes.csv')
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Tipos de datos
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ### Podemos visualizar que la data solo se compone por datos númericos, aunque la variable "Outcome" que indica si la persona padece de diabetes es una variable binaria o categorica de 0 y 1, igualmente no es necesario realizar un cambio ya que la libreria Pycaret lo reconoce como tal.

# %% [markdown]
# ## Preparación de los datos

# %%
# Verificar si hay datos nulos
diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ### Al no haber datos nulos y todas las variables presentan su formato correcto, no es necesario realizar algun cambio o limpieza en la data, por lo que podemos continuar.

# %% [markdown]
# ## Modelamiento

# %%
# Instalar libreria PyCaret
# !pip install pandas==2.1.4 matplotlib==3.7.5 # Por errores
# !pip install pycaret

# %%
# Cargamos data con esta librería
from pycaret.datasets import get_data
data = get_data('diabetes')
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from pycaret.classification import ClassificationExperiment
s = ClassificationExperiment()
s.setup(data, target = 'Outcome', session_id = 123)
# Out:
# <style type="text/css">
# #T_9c4f1_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9c4f1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c4f1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9c4f1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c4f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c4f1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9c4f1_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9c4f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c4f1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9c4f1_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_9c4f1_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = s.compare_models()
# Out:
# <style type="text/css">
# #T_3baed th {
#   text-align: left;
# }
# ...

# %% [markdown]
# ## Evaluación

# %%
s.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
pred_holdout = s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_886b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_886b2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_886b2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_886b2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_886b2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_886b2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_886b2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_886b2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_886b2_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_886b2_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
new_data = data.copy().drop('Outcome', axis = 1)
predictions = s.predict_model(best, data = new_data)

# %%
s.save_model(best, 'best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Pregnancies', 'Glucose',
#                                               'BloodPressure', 'SkinThickness',
#                                               'Insulin', 'BMI',
#                                               'DiabetesPedigreeFunction',
#                                               'Age'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
# ...

# %%
predictions
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0              6      148             72             35        0  33.599998
# 1              1       85             66             29        0  26.600000
# 2              8      183             64              0        0  23.299999
# 3              1       89             66             23       94  28.100000
# 4              0      137             40             35      168  43.099998
# ..           ...      ...            ...            ...      ...        ...
# 763           10      101             76             48      180  32.900002
# 764            2      122             70             27        0  36.799999
# 765            5      121             72             23      112  26.200001
# 766            1      126             60              0        0  30.100000
# 767            1       93             70             31        0  30.400000
#
# ...

# %% [markdown]
# ### Podemos visualizar que el modelo ya esta funcionando, según los resultados tiene un 0.76% de precisión, a simple vista vemos que se parece a los resultado de la data original. Este modelo nos puede ayudar a seguir analizando los factos con mayor influencia en el resultado de si padece diabetes o no y seguir mejorando el modelo.
